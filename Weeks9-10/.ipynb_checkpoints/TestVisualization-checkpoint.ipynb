# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.rc('figure', figsize=(10, 6))

# %%
sns.set(rc={'figure.figsize':(10,6)})

# %% [markdown]
# Load cleaned candy data from previous week:

# %%
candyDF = pd.read_csv('candy_cleaned.csv')

# %%
candyDF.head()
# Out:
#                  Timestamp TrickOrTreat  Gender   Age        Country  \
# 0  2016-10-24 05:09:23.033           No    Male  22.0         Canada
# 1  2016-10-24 05:09:54.798           No    Male  45.0  United States
# 2  2016-10-24 05:13:06.734           No  Female  48.0  United States
# 3  2016-10-24 05:14:17.192           No    Male  57.0  United States
# 4  2016-10-24 05:14:24.625          Yes    Male  42.0  United States
#
#          Locale  [100 Grand Bar]  \
# 0       Ontario              JOY
# 1            il              MEH
# 2      Colorado              JOY
# 3            il              JOY
# 4  South Dakota              MEH
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# 1                                                MEH
# 2                                            DESPAIR
# 3                                                MEH
# 4                                            DESPAIR
#
# ...

# %%
candyDF.columns
# Out:
# Index(['Timestamp', 'TrickOrTreat', 'Gender', 'Age', 'Country', 'Locale',
#        ' [100 Grand Bar]',
#        ' [Anonymous brown globs that come in black and orange wrappers]',
#        ' [Any full-sized candy bar]', ' [Black Jacks]',
#        ...
#        ' [Three Musketeers]', ' [Tolberone something or other]',
#        ' [Trail Mix]', ' [Twix]',
#        ' [Vials of pure high fructose corn syrup, for main-lining into your vein]',
#        ' [Vicodin]', ' [Whatchamacallit Bars]', ' [White Bread]',
#        ' [Whole Wheat anything]', ' [York Peppermint Patties]'],
#       dtype='object', length=106)

# %%
candyDF.Gender.unique()
# Out:
# array(['Male', 'Female', 'Other', "I'd rather not say", nan], dtype=object)

# %%
plt.scatter(candyDF.Timestamp, candyDF.Age, s=1, alpha=0.5)
plt.show()

# %%
candyDF.plot.scatter(x='Timestamp', y='Age', s=0.5, alpha=0.5)
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Age'>

# %%
candyDF.Timestamp[0]
# Out:
# '2016-10-24 05:09:23.033'

# %%
from datetime import datetime

# %%
candyDF.Timestamp[0].day
# Out:
# 24

# %%
type(candyDF.Timestamp[0])
# Out:
# str

# %%
type(candyDF.Timestamp)
# Out:
# pandas.core.series.Series

# %%
# candyDF.Timestamp = pd.to_datetime(candyDF.Timestamp)

# %%
type(candyDF.Timestamp)
# Out:
# pandas.core.series.Series

# %%
type(candyDF.Timestamp[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
candyDF.Timestamp[0]
# Out:
# Timestamp('2016-10-24 05:09:23.033000')

# %%
candyDF.Timestamp[0].time
# Out:
# <built-in method time of Timestamp object at 0x00000213E6068D60>

# %%
candyDF.Timestamp[0].strftime('%H:%M')
# Out:
# '05:09'

# %%
# candyDF.Timestamp[0].strptime('%H:%M')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-fb92142a7d45> in <module>
# ----> 1 candyDF.Timestamp[0].strptime('%H:%M')
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.strptime()
#
# TypeError: strptime() takes exactly 3 positional arguments (2 given)

# %%
print(candyDF.Timestamp[0].strftime('%H:%M'))
# Out:
# 05:09

# %%
candyDF.Timestamp.dt.time
# Out:
# 0       05:09:23.033000
# 1       05:09:54.798000
# 2       05:13:06.734000
# 3       05:14:17.192000
# 4       05:14:24.625000
#              ...
# 1254    16:53:52.516000
# 1255    06:53:54.735000
# 1256    11:06:10.827000
# 1257    16:07:26.539000
# 1258    17:06:45.660000
# Name: Timestamp, Length: 1259, dtype: object

# %% [markdown]
# #### Add a Time column

# %%
candyDF['Time'] = candyDF['Timestamp'].apply(lambda x: candyDF.to_datetime)

# %%
candyDF['Time'] = candyDF.Timestamp.strftime('%H:%M')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-ba85d7b6eaaf> in <module>
# ----> 1 candyDF['Time'] = candyDF.Timestamp.strptime('%H:%M')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strptime'

# %%
# candyDF['Time'] = candyDF.Timestamp.dt.time

# %%
candyDF.head()
# Out:
#                 Timestamp TrickOrTreat  Gender   Age        Country  \
# 0 2016-10-24 05:09:23.033           No    Male  22.0         Canada
# 1 2016-10-24 05:09:54.798           No    Male  45.0  United States
# 2 2016-10-24 05:13:06.734           No  Female  48.0  United States
# 3 2016-10-24 05:14:17.192           No    Male  57.0  United States
# 4 2016-10-24 05:14:24.625          Yes    Male  42.0  United States
#
#          Locale  [100 Grand Bar]  \
# 0       Ontario              JOY
# 1            il              MEH
# 2      Colorado              JOY
# 3            il              JOY
# 4  South Dakota              MEH
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# 1                                                MEH
# 2                                            DESPAIR
# 3                                                MEH
# 4                                            DESPAIR
#
# ...

# %%
candyDF.Time[0]
# Out:
# datetime.time(5, 9, 23, 33000)

# %%
# plt.scatter(candyDF.groupby(candyDF['Timestamp'].dt.hour), candyDF.Age)
# plt.show()

# %%
print(candyDF.Time[0])
# Out:
# 05:09:23.033000

# %%
# plt.scatter(candyDF.Time, candyDF.Age, s=5, alpha=0.5)
# plt.show()

# %%
candyDF = pd.read_csv('candy_cleaned.csv')

# %%
candyDF['Hour'] = candyDF.Timestamp.to_datetime.dt.hour
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-934561708e08> in <module>
# ----> 1 candyDF['Hour'] = candyDF.Timestamp.to_datetime.dt.hour
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_datetime'

# %%
candyDF['Hour'] = pd.to_datetime(candyDF.Timestamp).dt.hour

# %%
candyDF.Hour
# Out:
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
#         ..
# 1254    16
# 1255     6
# 1256    11
# 1257    16
# 1258    17
# Name: Hour, Length: 1259, dtype: int64

# %%
plt.scatter(candyDF.Hour, candyDF.Age, s=5, alpha=0.5)
plt.show()

# %% [markdown]
# # Here's one:

# %% [markdown]
# https://seaborn.pydata.org/tutorial/categorical.html

# %%
candyDF['Hour'] = pd.to_datetime(candyDF.Timestamp).dt.hour

# %%
plot = sns.regplot(x='Hour', y='Age', data=candyDF)
plot.set(xlabel="Hour of Day", ylabel='Age')
# Out:
# [Text(0.5, 0, 'Hour of Day'), Text(0, 0.5, 'Age')]

# %%
plot = sns.jointplot(x='Hour', y='Age', data=candyDF, kind='reg')
# plot.set(xlabel="Hour of Day", ylabel='Age')

# %%
plot = sns.lmplot(x='Hour', y='Age', hue='Gender', data=candyDF)
plot.set(xlabel="Hour of Day", ylabel='Age')

# %%
plot = sns.lmplot(x='Hour', y='Age', hue='TrickOrTreat',
                  col='Gender', col_wrap=2, data=candyDF)
plot.set(xlabel="Hour of Day", ylabel='Age')

# %%
sns.catplot(x='Hour', y='Age', hue='Gender', data=candyDF)

# %%
sns.catplot(x='Gender', y='Age', kind='box', data=candyDF)

# %%
sns.catplot(x='Gender', y='Age', kind='box', hue='TrickOrTreat', data=candyDF)

# %%
sns.catplot(x='TrickOrTreat', y='Age', kind='box', hue='Gender', data=candyDF)

# %%
sns.catplot(x='TrickOrTreat', y='Age', kind='violin', hue='Gender', data=candyDF)

# %%
sns.catplot(x='Gender', y='Age', kind='violin', hue='TrickOrTreat',
            split=True, inner='stick', data=candyDF)

# %%
sns.catplot(x=' [Nerds]', kind='count', data=candyDF)

# %%
sns.catplot(x=' [Twix]', kind='count', data=candyDF)

# %%
sns.catplot(x='TrickOrTreat', kind='count', hue=' [Nerds]', data=candyDF)

# %%
candyDF.columns
# Out:
# Index(['Timestamp', 'TrickOrTreat', 'Gender', 'Age', 'Country', 'Locale',
#        ' [100 Grand Bar]',
#        ' [Anonymous brown globs that come in black and orange wrappers]',
#        ' [Any full-sized candy bar]', ' [Black Jacks]',
#        ...
#        ' [Tolberone something or other]', ' [Trail Mix]', ' [Twix]',
#        ' [Vials of pure high fructose corn syrup, for main-lining into your vein]',
#        ' [Vicodin]', ' [Whatchamacallit Bars]', ' [White Bread]',
#        ' [Whole Wheat anything]', ' [York Peppermint Patties]', 'Hour'],
#       dtype='object', length=107)

# %%
candyDF[' [Twix]']
# Out:
# 0       JOY
# 1       JOY
# 2       JOY
# 3       JOY
# 4       JOY
#        ...
# 1254    JOY
# 1255    JOY
# 1256    JOY
# 1257    JOY
# 1258    JOY
# Name:  [Twix], Length: 1259, dtype: object

# %%
candyDF[' [Nerds]']
# Out:
# 0           JOY
# 1       DESPAIR
# 2           MEH
# 3           JOY
# 4           JOY
#          ...
# 1254        MEH
# 1255        JOY
# 1256        MEH
# 1257    DESPAIR
# 1258        MEH
# Name:  [Nerds], Length: 1259, dtype: object

# %%
sns.barplot(candyDF[' [Nerds]'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-6ca05628c466> in <module>
# ----> 1 sns.barplot(candyDF[' [Nerds]'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
plt.bar(candyDF[' [Nerds]'], height='count')
plt.show()

# %%
sns.barplot(x=' [Nerds]', y=' [Nerds]'.count(), data=candyDF)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-ffaaec6eab31> in <module>
# ----> 1 sns.barplot(x=' [Nerds]', y=' [Nerds]'.count(), data=candyDF)
#
# TypeError: count() takes at least 1 argument (0 given)
